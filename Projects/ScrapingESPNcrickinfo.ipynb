# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/kolkata-knight-riders-vs-sunrisers-hyderabad-final-1426312/match-overs-comparison"

# %%
page=requests.get(url)
soup=BeautifulSoup(page.text,'html')
table=soup.find_all('table',class_='ds-w-full ds-table ds-table-md ds-table-bordered ds-border-collapse ds-border ds-border-line ds-table-fixed')[0]
body=table.find_all('tr')

# %%
df=pd.DataFrame(columns=['Overs','Runs_1','Wkts_1','Runs_2','Runs_2'])

def return_data(a,b):
  try:
    data=row_indi_data[a].split('(')[1].split(' ')[b]
    return data
  except:
    return 0

lst=[]
o=1
for row in body[1:]:
  row_data=row.find_all("td")
  row_indi_data=[x.text.strip() for x in row_data]
  row_indi_data=row_indi_data[1:]
  # first_runs=row_indi_data[0].split('(')[1].split(' ')[0]
  # first_wkts=row_indi_data[0].split('(')[1].split(' ')[2]
  # second_runs=row_indi_data[1].split('(')[1].split(' ')[0]
  # second_wkts=row_indi_data[1].split('(')[1].split(' ')[2]
  first_runs=return_data(0,0)
  first_wkts=return_data(0,2)
  second_runs=return_data(1,0)
  second_wkts=return_data(1,2)
  lst=[o,int(first_runs),int(first_wkts),int(second_runs),int(second_wkts)]
  l=len(df)
  df.loc[l]=lst
  o+=1

df
# Out:
#     Overs  Runs_1  Wkts_1  Runs_2  Runs_2
# 0       1       3       1       5       0
# 1       2       3       1      12       1
# 2       3       9       0      20       0
# 3       4       6       0       9       0
# 4       5       2       1       6       0
# 5       6      17       0      20       0
# 6       7       7       1      12       0
# 7       8       4       0       9       0
# 8       9       7       0      13       1
# 9      10       3       0       5       0
# 10     11       9       1       3       0
# 11     12       2       1       0       0
# 12     13      10       1       0       0
# 13     14       8       0       0       0
# 14     15       0       1       0       0
# 15     16       8       0       0       0
# 16     17      10       0       0       0
# 17     18       5       1       0       0
# 18     19       0       1       0       0
